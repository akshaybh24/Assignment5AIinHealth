# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import graphviz

# %%
data = pd.read_csv('HEART.csv')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.model_selection import KFold

# %%
folds = 10
kf = KFold(n_splits=folds)
kf.split(data)
# Out:
# <generator object _BaseKFold.split at 0x0000022739792E60>

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

X = data[['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope']]
y = data['HeartDisease']

#perform label encoding with the data:

encoded_sex = LabelEncoder()
encoded_ChestPainType = LabelEncoder()
encoded_RestingECG = LabelEncoder()
encoded_ExerciseAngina = LabelEncoder()
encoded_ST_Slope = LabelEncoder()
encoded_HeartDisease = LabelEncoder()

# %%
data['encoded_sex'] = encoded_sex.fit_transform(data['Sex'])
data['encoded_ChestPainType'] = encoded_sex.fit_transform(data['ChestPainType'])
data['encoded_RestingECG'] = encoded_sex.fit_transform(data['RestingECG'])
data['encoded_ExerciseAngina'] = encoded_sex.fit_transform(data['ExerciseAngina'])
data['encoded_ST_Slope'] = encoded_sex.fit_transform(data['ST_Slope'])
data['encoded_HeartDisease'] = encoded_sex.fit_transform(data['HeartDisease'])

# %%
data.head(20)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# ...

# %%
new_df = data.drop(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope',  'HeartDisease' ], axis='columns')

# %%
new_X = new_df[['Age', 'encoded_sex', 'encoded_ChestPainType', 'encoded_RestingECG', 'Cholesterol', 'FastingBS', 'MaxHR', 'encoded_ExerciseAngina', 'Oldpeak', 'encoded_ST_Slope']]
new_y = new_df['encoded_HeartDisease']

# %%
k = 10
kf = KFold(n_splits=k)
kf.split(new_X)
# Out:
# <generator object _BaseKFold.split at 0x0000022739792D40>

# %%
from sklearn.metrics import accuracy_score

# %%
for train_index, test_index in kf.split(X):
    # Select rows based on indices
    X_train, X_test = new_X.iloc[train_index], new_X.iloc[test_index]
    y_train, y_test = new_y.iloc[train_index], new_y.iloc[test_index]

# %%
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)

# %%
    accuracy = accuracy_score(y_test, predictions)
    accuracies.append(accuracy)

# %%
print(f"Accuracies for each fold: {accuracies}")
print(f"Mean accuracy: {np.mean(accuracies)}")
# Out:
# Accuracies for each fold: [0.8021978021978022]
# Mean accuracy: 0.8021978021978022
